# %% [markdown]
# # **Matplotlib Python Library - IPL Data Set Project 1**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
ipl=pd.read_csv('CLEANED_IPL_Match_Dataset.csv')

# %%
ipl
# Out:
#            id  season        city        date   match_type  player_of_match  \
# 0      335982    2008   Bangalore  2008-04-18       League      BB McCullum
# 1      335983    2008  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984    2008       Delhi  2008-04-19       League      MF Maharoof
# 3      335985    2008      Mumbai  2008-04-20       League       MV Boucher
# 4      335986    2008     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...     ...         ...         ...          ...              ...
# 1090  1426307    2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309    2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310    2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311    2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312    2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %% [markdown]
# ##### 1. Create a line plot showing how many matches where played in each season

# %%
total_matches= ipl['season'].value_counts().sort_index()

# %%
total_matches
# Out:
# season
# 2008    58
# 2009    57
# 2010    60
# 2011    73
# 2012    74
# 2013    76
# 2014    60
# 2015    59
# 2016    60
# 2017    59
# 2018    60
# 2019    60
# 2020    60
# 2021    60
# 2022    74
# 2023    74
# 2024    71
# Name: count, dtype: int64

# %%
ipl['season'].unique()
# Out:
# array([2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018,
#        2019, 2020, 2021, 2022, 2023, 2024])

# %%
plt.plot(ipl['season'].unique(),total_matches,marker='o',markerfacecolor='red')
plt.title('Season Vs Total Number of Matches',color='blue')
plt.xlabel('Seasons',color='red')
plt.ylabel('Total Number of Matches',color='red')
# Out:
# Text(0, 0.5, 'Total Number of Matches')

# %% [markdown]
# ##### 2. Plot the average result_margin for each season using a line graph

# %%
avg_res=ipl.groupby(ipl['season'])['result_margin'].mean()

# %%
avg_res
# Out:
# season
# 2008    15.965517
# 2009    16.561404
# 2010    19.433333
# 2011    18.671233
# 2012    16.229730
# 2013    19.315789
# 2014    14.483333
# 2015    16.915254
# 2016    15.333333
# 2017    16.813559
# 2018    14.350000
# 2019    14.450000
# 2020    21.083333
# 2021    13.350000
# 2022    16.972973
# 2023    18.986486
# 2024    17.873239
# Name: result_margin, dtype: float64

# %%
plt.plot(ipl['season'].unique(),avg_res,marker='o',markerfacecolor='red')
plt.title('Season Vs Average Result Margin',color='blue')
plt.xlabel('Seasons',color='red')
plt.ylabel('Result Margin',color='red')
# Out:
# Text(0, 0.5, 'Result Margin')

# %% [markdown]
# ##### 3. Create a line plot showing the count of matches with super_over == 'Yes' for every season

# %%
super_matches=ipl[ipl['super_over']=='Yes']
super_matches
# Out:
#           id  season       city        date match_type player_of_match  \
# 66    392190    2009  Cape Town  2009-04-23     League       YK Pathan
# 130   419121    2010    Chennai  2010-03-21     League        J Theron
# 328   598004    2013  Hyderabad  2013-04-07     League       GH Vihari
# 342   598017    2013  Bangalore  2013-04-16     League         V Kohli
# 416   729315    2014  Abu Dhabi  2014-04-29     League     JP Faulkner
# 475   829741    2015  Ahmedabad  2015-04-21     League        SE Marsh
# 610  1082625    2017     Rajkot  2017-04-29     League       KH Pandya
# 705  1175365    2019      Delhi  2019-03-30     League         PP Shaw
# 746  1178426    2019     Mumbai  2019-05-02     League       JJ Bumrah
# 757  1216493    2020    UnKnown  2020-09-20     League      MP Stoinis
# 765  1216547    2020    UnKnown  2020-09-28     League  AB de Villiers
# 790  1216512    2020  Abu Dhabi  2020-10-18     League     LH Ferguson
# ...

# %%
count_of_matches=super_matches['season'].value_counts().sort_index()
count_of_matches
# Out:
# season
# 2009    1
# 2010    1
# 2013    2
# 2014    1
# 2015    1
# 2017    1
# 2019    2
# 2020    4
# 2021    1
# Name: count, dtype: int64

# %%
plt.plot(count_of_matches.index, count_of_matches.values, marker='o', markerfacecolor='red')
plt.title('Season Vs Number of Super Over Matches', color='blue')
plt.xlabel('Seasons', color='red')
plt.ylabel('Number of Super Over Matches', color='red')
plt.show()

# %% [markdown]
# ##### 4. Create a line plot  comparing number of times teams choose batting but number of times teams choose field.

# %%
bat_decision = (
    ipl[ipl['toss_decision'] == 'Batting']
    .groupby('season')['id']
    .count()
)
field_decision = (
    ipl[ipl['toss_decision'] == 'Fielding']
    .groupby('season')['id']
    .count()
)
plt.figure(figsize=(10,5))
plt.plot(bat_decision.index, bat_decision.values,
         marker='o', label='Bat First')
plt.plot(field_decision.index, field_decision.values,
         marker='o', label='Field First')
plt.title('Toss Decision Trend Over Seasons')
plt.xlabel('Season')
plt.ylabel('Count')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ##### 5. Create a team (example Mumbai Indians or CSK) and plot the number of matches won by the team in each season

# %%
team_name = 'Mumbai Indians'
team_wins = (
    ipl[ipl['winner'] == team_name]
    .groupby('season')['id']
    .count()
)
plt.figure(figsize=(10,5))
plt.plot(team_wins.index, team_wins.values, marker='o')
plt.title(f'{team_name} Wins Per Season')
plt.xlabel('Season')
plt.ylabel('Number of Wins')
plt.grid(True)
plt.show()

# %%
mi=ipl[ipl['winner']=='Mumbai Indians'].groupby('season')['winner'].count()

# %%
mi
# Out:
# season
# 2008     7
# 2009     5
# 2010    11
# 2011    10
# 2012    10
# 2013    13
# 2014     7
# 2015    10
# 2016     7
# 2017    12
# 2018     6
# 2019    11
# 2020    11
# 2021     7
# 2022     4
# 2023     9
# 2024     4
# Name: winner, dtype: int64

# %%
mi.plot(marker='o',markersize=8,lw=2,color='orange',markerfacecolor='white',markeredgecolor='blue',label='Mumbai Indians')
plt.grid(True)
plt.show()

# %%
mi=ipl[ipl['winner']=='Mumbai Indians'].groupby('season')['winner'].count()
rcb=ipl[ipl['winner']=='Royal Challengers Bengaluru'].groupby('season')['winner'].count()

# %%
pd.DataFrame([mi,rcb])
# Out:
# season  2008  2009  2010  2011  2012  2013  2014  2015  2016  2017  2018  \
# winner     7     5    11    10    10    13     7    10     7    12     6
# winner     4     9     8    10     8     9     5     8     9     3     6
#
# season  2019  2020  2021  2022  2023  2024
# winner    11    11     7     4     9     4
# winner     5     7     9     9     7     7

# %%
mi.plot(marker='o',markersize=8,lw=3,color='blue',markerfacecolor='white',markeredgecolor='black',label='Mumbai Indians')
rcb.plot(marker='o',markersize=8,lw=3,color='red',markerfacecolor='white',markeredgecolor='black',label='Royal Challengers Bengaluru')
plt.grid(True)
plt.show()

# %%
team_name = 'Mumbai Indians'
team_wins = (
    ipl[ipl['winner'] == team_name]
    .groupby('season')['id']
    .count()
)
plt.figure(figsize=(10,5))
plt.plot(team_wins.index, team_wins.values, lw=4,marker='o',markerfacecolor='white',markeredgecolor='black')
plt.title(f'{team_name} Wins Per Season')
plt.xlabel('Season')
plt.ylabel('Number of Wins')
plt.grid(True)
plt.show()

# %% [markdown]
# ### subplot()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15,12))

# ====================== 1st Figure ======================
total_matches = ipl['season'].value_counts().sort_index()

plt.subplot(3,2,1)
plt.plot(total_matches.index,
         total_matches.values,
         marker='o',
         markerfacecolor='red')

plt.title('Season Vs Total Number of Matches', color='blue')
plt.xlabel('Seasons', color='red')
plt.ylabel('Total Number of Matches', color='red')
plt.grid(True)


# ====================== 2nd Figure ======================
avg_res = ipl.groupby('season')['result_margin'].mean()

plt.subplot(3,2,2)
plt.plot(avg_res.index,
         avg_res.values,
         marker='o',
         markerfacecolor='red')

plt.title('Season Vs Average Result Margin', color='blue')
plt.xlabel('Seasons', color='red')
plt.ylabel('Result Margin', color='red')
plt.grid(True)


# ====================== 3rd Figure ======================
super_matches = ipl[ipl['super_over'] == 'Yes']

count_of_matches = (
    super_matches['season']
    .value_counts()
    .sort_index()
)

plt.subplot(3,2,3)
plt.plot(count_of_matches.index,
         count_of_matches.values,
         marker='o',
         markerfacecolor='red')

plt.title('Season Vs Number of Super Over Matches', color='blue')
plt.xlabel('Seasons', color='red')
plt.ylabel('Number of Super Over Matches', color='red')
plt.grid(True)


# ====================== 4th Figure ======================
bat_decision = (
    ipl[ipl['toss_decision'] == 'Batting']
    .groupby('season')['id']
    .count()
)

field_decision = (
    ipl[ipl['toss_decision'] == 'Fielding']
    .groupby('season')['id']
    .count()
)

plt.subplot(3,2,4)

plt.plot(bat_decision.index,
         bat_decision.values,
         marker='o',
         label='Bat First')

plt.plot(field_decision.index,
         field_decision.values,
         marker='o',
         label='Field First')

plt.title('Toss Decision Trend Over Seasons')
plt.xlabel('Season')
plt.ylabel('Count')
plt.legend()
plt.grid(True)


# ====================== 5th Figure ======================
team_name = 'Mumbai Indians'

team_wins = (
    ipl[ipl['winner'] == team_name]
    .groupby('season')['id']
    .count()
)

plt.subplot(3,2,5)

plt.plot(team_wins.index,
         team_wins.values,
         marker='o',
         markerfacecolor='red')

plt.title(f'{team_name} Wins Per Season')
plt.xlabel('Season')
plt.ylabel('Number of Wins')
plt.grid(True)


# ====================== Layout ======================
plt.tight_layout()
plt.show()
