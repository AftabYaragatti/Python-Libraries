# %%
import pandas as pd
import numpy as np
df=pd.read_csv('https://raw.githubusercontent.com/Taj1920/Data-Analysis-Datasets/refs/heads/main/Datasets-Practice/hr_data.csv')

# %%
df
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 0             1003               2                   157                   3
# 1             1005               5                   262                   6
# 2             1486               7                   272                   4
# 3             1038               5                   223                   5
# 4             1057               2                   159                   3
# ...            ...             ...                   ...                 ...
# 14994        87670               2                   151                   3
# 14995        87673               2                   160                   3
# 14996        87679               2                   143                   3
# 14997        87681               6                   280                   4
# 14998        87684               2                   158                   3
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   employee_id            14999 non-null  int64
#  1   number_project         14999 non-null  int64
#  2   average_montly_hours   14999 non-null  int64
#  3   time_spend_company     14999 non-null  int64
#  4   Work_accident          14999 non-null  int64
#  5   left                   14999 non-null  int64
#  6   promotion_last_5years  14999 non-null  int64
#  7   department             14999 non-null  object
#  8   salary                 14999 non-null  object
# dtypes: int64(7), object(2)
# memory usage: 1.0+ MB

# %%
df['department'].unique()
# Out:
# array(['sales', 'accounting', 'hr', 'technical', 'support', 'management',
#        'IT', 'product_mng', 'marketing', 'RandD'], dtype=object)

# %%
df[df['department']=='IT']
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 61            1399               7                   308                   4
# 62            1404               6                   244                   5
# 63            1413               2                   132                   3
# 64           42423               6                   286                   4
# 65            1424               6                   161                   4
# ...            ...             ...                   ...                 ...
# 14930        87284               6                   268                   4
# 14931        87288               5                   240                   5
# 14932        87294               2                   127                   3
# 14933        87308               7                   264                   4
# 14938        45511               4                   271                   5
#
# ...

# %%
df[df['department']=='IT']
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 61            1399               7                   308                   4
# 62            1404               6                   244                   5
# 63            1413               2                   132                   3
# 64           42423               6                   286                   4
# 65            1424               6                   161                   4
# ...            ...             ...                   ...                 ...
# 14930        87284               6                   268                   4
# 14931        87288               5                   240                   5
# 14932        87294               2                   127                   3
# 14933        87308               7                   264                   4
# 14938        45511               4                   271                   5
#
# ...

# %%
df[df['department']=='IT']['number_project'].sum()
# Out:
# np.int64(4683)

# %%
df[df['department']=='RandD']
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 301           2847               3                   278                   4
# 302          57006               7                   250                   5
# 303           2880               2                   127                   3
# 304           2881               5                   255                   5
# 305           2882               2                   135                   3
# ...            ...             ...                   ...                 ...
# 14939        87333               4                   273                   5
# 14940        87335               5                   285                   4
# 14941        87339               2                   131                   3
# 14942        87341               5                   135                   6
# 14943        96411               5                   239                   5
#
# ...

# %%
df[df['department']=='RandD'].sum()
# Out:
# employee_id                                                       32948168
# number_project                                                        3033
# average_montly_hours                                                158030
# time_spend_company                                                    2650
# Work_accident                                                          134
# left                                                                   121
# promotion_last_5years                                                   27
# department               RandDRandDRandDRandDRandDRandDRandDRandDRandDR...
# salary                   mediummediummediummediummediummediummediummedi...
# dtype: object

# %%
df[df['department']=='RandD']['number_project'].sum()
# Out:
# np.int64(3033)

# %%
df.groupby('department').count()
# Out:
#              employee_id  number_project  average_montly_hours  \
# department
# IT                  1227            1227                  1227
# RandD                787             787                   787
# accounting           767             767                   767
# hr                   739             739                   739
# management           630             630                   630
# marketing            858             858                   858
# product_mng          902             902                   902
# sales               4140            4140                  4140
# support             2229            2229                  2229
# technical           2720            2720                  2720
#
#              time_spend_company  Work_accident  left  promotion_last_5years  \
# department
# IT                         1227           1227  1227                   1227
# RandD                       787            787   787                    787
# ...

# %% [markdown]
# ##### **Group By Questions**

# %% [markdown]
# ##### 1. Group by department and find the average mothly hours of employees in each department.

# %%
df.groupby(['department'])['average_montly_hours'].sum()
# Out:
# department
# IT             248119
# RandD          158030
# accounting     154292
# hr             146828
# management     126787
# marketing      171073
# product_mng    180369
# sales          831773
# support        447490
# technical      550793
# Name: average_montly_hours, dtype: int64

# %% [markdown]
# ##### 2.Group by department and calculate the total number of employees in each department.

# %%
df.groupby(['department'])['employee_id'].count()
# Out:
# department
# IT             1227
# RandD           787
# accounting      767
# hr              739
# management      630
# marketing       858
# product_mng     902
# sales          4140
# support        2229
# technical      2720
# Name: employee_id, dtype: int64

# %% [markdown]
# ##### 3.Group by number_project and find the average time spent in the company

# %%
df.groupby(['number_project'])['time_spend_company'].mean()
# Out:
# number_project
# 2    3.180486
# 3    3.286560
# 4    3.454983
# 5    3.800072
# 6    4.192504
# 7    4.113281
# Name: time_spend_company, dtype: float64

# %% [markdown]
# ##### 4.Group by department and compute : average monthly  hours average number of projects.

# %%
df.groupby('department')[['average_montly_hours','number_project']].mean()
# Out:
#              average_montly_hours  number_project
# department
# IT                     202.215974        3.816626
# RandD                  200.800508        3.853875
# accounting             201.162973        3.825293
# hr                     198.684709        3.654939
# management             201.249206        3.860317
# marketing              199.385781        3.687646
# product_mng            199.965632        3.807095
# sales                  200.911353        3.776329
# support                200.758188        3.803948
# technical              202.497426        3.877941

# %% [markdown]
# ##### 5.Group by left and find : average monthly hours average time spent in the company.

# %%
df.groupby('left')[['average_montly_hours','time_spend_company']].mean()
# Out:
#       average_montly_hours  time_spend_company
# left
# 0               199.060203            3.380032
# 1               207.419210            3.876505

# %% [markdown]
# ##### 6.Group by department and left, then find the average monthly hours

# %%
df.groupby(['department','left'])['average_montly_hours'].count()
# Out:
# department   left
# IT           0        954
#              1        273
# RandD        0        666
#              1        121
# accounting   0        563
#              1        204
# hr           0        524
#              1        215
# management   0        539
#              1         91
# marketing    0        655
#              1        203
# product_mng  0        704
#              1        198
# sales        0       3126
#              1       1014
# support      0       1674
#              1        555
# technical    0       2023
#              1        697
# Name: average_montly_hours, dtype: int64

# %% [markdown]
# ##### 7.Group by number_project and promotion_last_5Years, then calculate the employee count.

# %%
df.groupby(['number_project','promotion_last_5years'])['employee_id'].count()
# Out:
# number_project  promotion_last_5years
# 2               0                        2351
#                 1                          37
# 3               0                        3960
#                 1                          95
# 4               0                        4248
#                 1                         117
# 5               0                        2711
#                 1                          50
# 6               0                        1154
#                 1                          20
# 7               0                         256
# Name: employee_id, dtype: int64

# %% [markdown]
# ##### 8. Group by department and work_accident, then find the average time spent in the company.

# %% [markdown]
# ##### 9.Group by department and calculate multiple aggrigations : mean of the average_monthly_hours max of time _spend_company sum of work_accident.

# %% [markdown]
# ##### 10.Group by department and left, then use agg() to compute : average monthly hours minimum and maximum number of projects count of employees.

# %% [markdown]
# ##### **Amazon data set**

# %%
import pandas as pd
import numpy as np
amazon_df=pd.read_csv('amazon_fires (1).csv',encoding='ISO-8859-1')

# %%
amazon_df
# Out:
#        ano       mes     estado   numero  encontro
# 0     1998   Janeiro       Acre  0 Fires  1/1/1998
# 1     1999   Janeiro       Acre  0 Fires  1/1/1999
# 2     2000   Janeiro       Acre  0 Fires  1/1/2000
# 3     2001   Janeiro       Acre  0 Fires  1/1/2001
# 4     2002   Janeiro       Acre  0 Fires  1/1/2002
# ...    ...       ...        ...      ...       ...
# 6449  2012  Dezembro  Tocantins      128  1/1/2012
# 6450  2013  Dezembro  Tocantins       85  1/1/2013
# 6451  2014  Dezembro  Tocantins      223  1/1/2014
# 6452  2015  Dezembro  Tocantins      373  1/1/2015
# 6453  2016  Dezembro  Tocantins      119  1/1/2016
#
# [6454 rows x 5 columns]

# %% [markdown]
# ##### 1. Number of employees who got fired in the month of january.

# %% [markdown]
# ##### 2.Number of people who got fired in 2002(need features enhgineering)

# %% [markdown]
# ##### 3. Number of fires in year 2001 in Tocantins

# %% [markdown]
# ##### **Titanic data set**

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('https://raw.githubusercontent.com/Taj1920/Data-Analysis-Datasets/refs/heads/main/Datasets-Practice/titanic.csv')

# %%
df
# Out:
#       pclass                                             name     sex  \
# 0          1                    Allen, Miss. Elisabeth Walton  female
# 1          1                   Allison, Master. Hudson Trevor    male
# 2          1                     Allison, Miss. Helen Loraine  female
# 3          1             Allison, Mr. Hudson Joshua Creighton    male
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...      ...                                              ...     ...
# 1304       3                             Zabour, Miss. Hileni  female
# 1305       3                            Zabour, Miss. Thamine  female
# 1306       3                        Zakarian, Mr. Mapriededer    male
# 1307       3                              Zakarian, Mr. Ortin    male
# 1308       3                               Zimmerman, Mr. Leo    male
#
#           age  sibsp  parch  ticket      fare    cabin embarked  survived
# ...

# %% [markdown]
# ##### 1.How many peoples are survived in b5 cabin

# %%
df=df.groupby('cabin')['survived'].sum().get('B5')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df=df.groupby('cabin')['survived'].sum().get('B5')
#
# File C:\Python313\Lib\site-packages\pandas\core\groupby\groupby.py:1363, in GroupBy.__getattr__(self, attr)
#    1360 if attr in self.obj:
#    1361     return self[attr]
# -> 1363 raise AttributeError(
#    1364     f"'{type(self).__name__}' object has no attribute '{attr}'"
#    1365 )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'groupby'

# %%
df.groupby('cabin')['B5'].count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 df.groupby('cabin')['B5'].count()
#
# File C:\Python313\Lib\site-packages\pandas\core\groupby\groupby.py:1363, in GroupBy.__getattr__(self, attr)
#    1360 if attr in self.obj:
#    1361     return self[attr]
# -> 1363 raise AttributeError(
#    1364     f"'{type(self).__name__}' object has no attribute '{attr}'"
#    1365 )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'groupby'

# %% [markdown]
# ##### 2.count of females whose age is less than 20 and survived

# %%
df.groupby(df[df['sex'=='fe])
# Out:
#   Cell In[16], line 1
#     df.groupby(df[df['age'<20] & (df[df['survived']==1]])])
#                                                        ^
# SyntaxError: closing parenthesis ']' does not match opening parenthesis '('

# %% [markdown]
# ##### 3.Total fare paid by embarked S females.

# %% [markdown]
# ##### 4.count of ppl in pclass 3 having only 1 person with them

# %% [markdown]
# ##### 5.maximum fare paid in embarked Q

# %% [markdown]
# ##### **HR Data set**

# %% [markdown]
# ##### 1.Avg time spend by the ppl in support department who got promoted
