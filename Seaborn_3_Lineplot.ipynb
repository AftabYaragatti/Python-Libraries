# %% [markdown]
# # **Seaborn Library for Data Analytics**

# %% [markdown]
# ### **Lineplot in Data Analytics**
# #### **What is a Line Plot :**
# ##### A Line Plot is used to show the relationship between variables by connecting data points with lines.
# ##### **It is mainly used for:**
# ##### Trend Analysis
# ##### Time Series Analysis
# ##### Sales Analysis
# ##### Stock Market Analysis
# ##### Growth Analysis
# ##### **Example**
# | Month | Sales |
# | ----- | ----- |
# | Jan   | 100   |
# | Feb   | 120   |
# | Mar   | 150   |
# | Apr   | 180   |
# | May   | 200   |
# ##### The points are connected using a line.
# ##### **Why Use Line Plot :**
# ##### Show trends over time
# ##### Time Series Analysis
# ##### Revenue Growth Analysis
# ##### Stock Market Analysis
# ##### Business Reporting
# ##### Forecasting
# ##### Machine Learning EDA
# ##### **Syntax :** sns.lineplot(
#     data=None,
#     x=None,
#     y=None,
#     hue=None,
#     style=None,
#     size=None,
#     palette=None,
#     color=None,
#     marker=None,
#     markers=False,
#     dashes=True,
#     linewidth=2,
#     alpha=None,
#     estimator='mean',
#     errorbar=('ci',95),
#     legend='auto'
# )
# | X-axis      | Y-axis      | Valid?            |
# | ----------- | ----------- | ----------------- |
# | Numerical   | Numerical   | ✅ Yes             |
# | Date/Time   | Numerical   | ✅ Most Common     |
# | Categorical | Numerical   | ✅ Yes             |
# | Numerical   | Categorical | ❌ No              |
# | Categorical | Categorical | ❌ Not Recommended |

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('Pyspider_Dataset.csv')
df
# Out:
#       Student Name  Phone Number              Email ID Admission Type  \
# 0       Stud_00001    6633812187  Stud_00001@gmail.com           PAID
# 1       Stud_00002    8268566422  Stud_00002@gmail.com           PAID
# 2       Stud_00003    6713245593  Stud_00003@gmail.com           PAID
# 3       Stud_00004    9033992219  Stud_00004@gmail.com           PAID
# 4       Stud_00005    6117831905  Stud_00005@gmail.com           PAID
# ...            ...           ...                   ...            ...
# 29995   Stud_29996    6836367122  Stud_29996@gmail.com            INC
# 29996   Stud_29997    7240584616  Stud_29997@gmail.com           PAID
# 29997   Stud_29998    8626614297  Stud_29998@gmail.com           PAID
# 29998   Stud_29999    8047150629  Stud_29999@gmail.com           PAID
# 29999   Stud_30000    7235331199  Stud_30000@gmail.com           PAID
#
#                       Courses Taken  Tenth YOP  Tenth Percentage  Twelth YOP  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Student Name               30000 non-null  object
#  1   Phone Number               30000 non-null  int64
#  2   Email ID                   30000 non-null  object
#  3   Admission Type             30000 non-null  object
#  4   Courses Taken              30000 non-null  object
#  5   Tenth YOP                  30000 non-null  int64
#  6   Tenth Percentage           30000 non-null  float64
#  7   Twelth YOP                 30000 non-null  int64
#  8   Twelth Percentage          30000 non-null  float64
#  9   Degree Yop                 30000 non-null  int64
#  10  Degree Stream              30000 non-null  object
#  11  Degree Percentage          30000 non-null  float64
#  12  Masters Degree YOP         30000 non-null  int64
# ...

# %%
df=df[:51]
df
# Out:
#    Student Name  Phone Number              Email ID Admission Type  \
# 0    Stud_00001    6633812187  Stud_00001@gmail.com           PAID
# 1    Stud_00002    8268566422  Stud_00002@gmail.com           PAID
# 2    Stud_00003    6713245593  Stud_00003@gmail.com           PAID
# 3    Stud_00004    9033992219  Stud_00004@gmail.com           PAID
# 4    Stud_00005    6117831905  Stud_00005@gmail.com           PAID
# 5    Stud_00006    6950033815  Stud_00006@gmail.com           PAID
# 6    Stud_00007    6194616233  Stud_00007@gmail.com           PAID
# 7    Stud_00008    8703931061  Stud_00008@gmail.com           PAID
# 8    Stud_00009    7759268842  Stud_00009@gmail.com            INC
# 9    Stud_00010    7205483456  Stud_00010@gmail.com           PAID
# 10   Stud_00011    8514201002  Stud_00011@gmail.com           PAID
# 11   Stud_00012    6727068139  Stud_00012@gmail.com           PAID
# 12   Stud_00013    6507888778  Stud_00013@gmail.com            INC
# ...

# %%
sns.lineplot(data=df,x='Degree Yop',y='Degree Percentage')
plt.title('Scatter Plot (Degree YOP VS PERCENTAGE',fontsize=15,color='red',fontstyle='italic',fontfamily='Times New Roman')
plt.xlabel('Degree YOP',color='purple',fontsize=12)
plt.ylabel('Degree Percentage',color='purple',fontsize=12)
plt.xticks(color='blue',rotation=90)
plt.yticks(color='blue',rotation=0)
plt.grid(True)
plt.legend(loc='best',bbox_to_anchor=(1.05,1),)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_5416\402464919.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(loc='best',bbox_to_anchor=(1.05,1),)

# %% [markdown]
# #### **hue :**
# ##### Creates multiple colored lines.
# ##### **Example :** hue='Year'
# ##### **Example :** sns.lineplot(
#     data=df,
#     x='Month',
#     y='Sales',
#     hue='Year'
# )

# %%
sns.lineplot(data=df,x='Degree Yop',y='Degree Percentage',hue='Courses Taken')
plt.title('Scatter Plot (Degree YOP VS PERCENTAGE',fontsize=15,color='red',fontstyle='italic',fontfamily='Times New Roman')
plt.xlabel('Degree YOP',color='purple',fontsize=12)
plt.ylabel('Degree Percentage',color='purple',fontsize=12)
plt.xticks(color='blue',rotation=90)
plt.yticks(color='blue',rotation=0)
plt.grid(True)
plt.legend(loc='best',bbox_to_anchor=(1.05,1),)
plt.tight_layout()
plt.show()

# %%
sns.lineplot(data=df,x='Degree Yop',y='Degree Percentage',hue='Admission Type')
plt.title('Scatter Plot (Degree YOP VS PERCENTAGE',fontsize=15,color='red',fontstyle='italic',fontfamily='Times New Roman')
plt.xlabel('Degree YOP',color='purple',fontsize=12)
plt.ylabel('Degree Percentage',color='purple',fontsize=12)
plt.xticks(color='blue',rotation=90)
plt.yticks(color='blue',rotation=0)
plt.grid(True)
plt.legend(loc='best',bbox_to_anchor=(1.05,1),)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### **Style :**
# ##### Different line styles.
# ##### **Example :**
# ##### style='Region'
# ##### **Output :**
# ##### North → Solid
# ##### South → Dashed
# ##### East → Dotted
# ##### West → Dash-dot

# %%
sns.lineplot(data=df,x='Degree Yop',y='Degree Percentage',hue='Courses Taken',style='Admission Type')
plt.title('Scatter Plot (Degree YOP VS PERCENTAGE',fontsize=15,color='red',fontstyle='italic',fontfamily='Times New Roman')
plt.xlabel('Degree YOP',color='purple',fontsize=12)
plt.ylabel('Degree Percentage',color='purple',fontsize=12)
plt.xticks(color='blue',rotation=90)
plt.yticks(color='blue',rotation=0)
plt.grid(True)
plt.legend(loc='best',bbox_to_anchor=(1.05,1),)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### **Size :**
# ##### Controls line thickness.
# ##### **Example :** size='Profit'
# ##### Higher Profit → Thicker Line

# %%
sns.lineplot(data=df,x='Degree Yop',y='Degree Percentage',hue='Courses Taken',size='Admission Type')
plt.title('Scatter Plot (Degree YOP VS PERCENTAGE',fontsize=15,color='red',fontstyle='italic',fontfamily='Times New Roman')
plt.xlabel('Degree YOP',color='purple',fontsize=12)
plt.ylabel('Degree Percentage',color='purple',fontsize=12)
plt.xticks(color='blue',rotation=90)
plt.yticks(color='blue',rotation=0)
plt.grid(True)
plt.legend(loc='best',bbox_to_anchor=(1.05,1),)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### **palette :**
# ##### Color theme.
# ##### **Syntax :** palette='Set2'
# ##### Most Used Palette Values
# ##### **Qualitative**
# ##### palette='deep'
# ##### palette='muted'
# ##### palette='bright'
# ##### palette='pastel'
# ##### palette='dark'
# ##### palette='colorblind'
# ##### **Set Palettes**
# ##### palette='Set1'
# ##### palette='Set2'
# ##### palette='Set3'
# ##### **Sequential**
# ##### palette='Blues'
# ##### palette='Greens'
# ##### palette='Reds'
# ##### palette='Purples'
# ##### **Diverging**
# ##### palette='coolwarm'
# ##### palette='Spectral'
# ##### palette='RdYlBu'
# ##### **Scientific**
# ##### palette='viridis'
# ##### palette='magma'
# ##### palette='plasma'
# ##### palette='inferno'
# ##### palette='cividis'
# ##### **Example :** sns.scatterplot(
#     data=df,
#     x='Age',
#     y='Salary',
#     hue='Gender',
#     palette='Set2'
# )

# %%
sns.lineplot(data=df,x='Degree Yop',y='Degree Percentage',hue='Courses Taken',size='Admission Type',palette='Set2')
plt.title('Scatter Plot (Degree YOP VS PERCENTAGE',fontsize=15,color='red',fontstyle='italic',fontfamily='Times New Roman')
plt.xlabel('Degree YOP',color='purple',fontsize=12)
plt.ylabel('Degree Percentage',color='purple',fontsize=12)
plt.xticks(color='blue',rotation=90)
plt.yticks(color='blue',rotation=0)
plt.grid(True)
plt.legend(loc='best',bbox_to_anchor=(1.05,1),)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### **color :**
# ##### Single color for all points.
# ##### **Syntax :** color='red'
# ##### **Common Colors :** red, green, blue, black, yellow, orange, purple, pink, brown, gray, cyan, magenta.
# ##### **Example :** sns.scatterplot(
#     data=df,
#     x='Age',
#     y='Salary',
#     color='green'
# )

# %%
sns.lineplot(data=df,x='Degree Yop',y='Degree Percentage',color='magenta')
plt.title('Scatter Plot (Degree YOP VS PERCENTAGE',fontsize=15,color='red',fontstyle='italic',fontfamily='Times New Roman')
plt.xlabel('Degree YOP',color='purple',fontsize=12)
plt.ylabel('Degree Percentage',color='purple',fontsize=12)
plt.xticks(color='blue',rotation=90)
plt.yticks(color='blue',rotation=0)
plt.grid(True)
plt.legend(loc='best',bbox_to_anchor=(1.05,1),)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_5416\3229688643.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(loc='best',bbox_to_anchor=(1.05,1),)

# %% [markdown]
# #### **marker :**
# ##### Fixed marker shape.
# ##### **Syntax :** marker='o'
# | Marker | Shape          |
# | ------ | -------------- |
# | o      | Circle         |
# | s      | Square         |
# | ^      | Triangle Up    |
# | v      | Triangle Down  |
# | *      | Star           |
# | +      | Plus           |
# | x      | Cross          |
# | D      | Diamond        |
# | p      | Pentagon       |
# | H      | Hexagon        |
# | <      | Left Triangle  |
# | >      | Right Triangle |

# %%
sns.lineplot(data=df,x='Degree Yop',y='Degree Percentage',hue='Courses Taken',size='Admission Type',marker='D')
plt.title('Scatter Plot (Degree YOP VS PERCENTAGE',fontsize=15,color='red',fontstyle='italic',fontfamily='Times New Roman')
plt.xlabel('Degree YOP',color='purple',fontsize=12)
plt.ylabel('Degree Percentage',color='purple',fontsize=12)
plt.xticks(color='blue',rotation=90)
plt.yticks(color='blue',rotation=0)
plt.grid(True)
plt.legend(loc='best',bbox_to_anchor=(1.05,1),)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### **markers :**
# ##### Enable marker mapping when using style(True/False)
# ##### **markers=True :** Adds marker symbols to data points.

# %%
sns.lineplot(data=df,x='Degree Yop',y='Degree Percentage',hue='Courses Taken',size='Admission Type',marker='D',markers=True)
plt.title('Scatter Plot (Degree YOP VS PERCENTAGE',fontsize=15,color='red',fontstyle='italic',fontfamily='Times New Roman')
plt.xlabel('Degree YOP',color='purple',fontsize=12)
plt.ylabel('Degree Percentage',color='purple',fontsize=12)
plt.xticks(color='blue',rotation=90)
plt.yticks(color='blue',rotation=0)
plt.grid(True)
plt.legend(loc='best',bbox_to_anchor=(1.05,1),)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### **dashes :**
# ##### Controls dashed lines.(True/False)
# ##### Seaborn uses different line styles:
# ##### Solid line (-)
# ##### Dashed line (--)
# ##### Dotted line (:)
# ##### Dash-dot line (-.)
# ##### dashes=True + linestyle=':'
# ##### These can conflict.
# ##### When you use: dashes=True
# ##### Seaborn automatically assigns different dash patterns.
# ##### Then: linestyle=':' tries to make all lines dotted.So choose one.

# %%
sns.lineplot(data=df,x='Degree Yop',y='Degree Percentage',hue='Courses Taken',marker='D',dashes=True)
plt.title('Scatter Plot (Degree YOP VS PERCENTAGE',fontsize=15,color='red',fontstyle='italic',fontfamily='Times New Roman')
plt.xlabel('Degree YOP',color='purple',fontsize=12)
plt.ylabel('Degree Percentage',color='purple',fontsize=12)
plt.xticks(color='blue',rotation=90)
plt.yticks(color='blue',rotation=0)
plt.grid(True)
plt.legend(loc='best',bbox_to_anchor=(1.05,1),)
plt.tight_layout()
plt.show()

# %%
sns.lineplot(data=df,x='Degree Yop',y='Degree Percentage',hue='Courses Taken',marker='D',dashes=False)
plt.title('Scatter Plot (Degree YOP VS PERCENTAGE',fontsize=15,color='red',fontstyle='italic',fontfamily='Times New Roman')
plt.xlabel('Degree YOP',color='purple',fontsize=12)
plt.ylabel('Degree Percentage',color='purple',fontsize=12)
plt.xticks(color='blue',rotation=90)
plt.yticks(color='blue',rotation=0)
plt.grid(True)
plt.legend(loc='best',bbox_to_anchor=(1.05,1),)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### **legend :**
# ##### Controls legend display.
# ##### **Values**
# ##### legend='auto'
# ##### legend='brief'
# ##### legend='full'
# ##### legend=False
# ##### **legend='auto' (Default)**
# ##### Seaborn automatically decides how much information to show.
# ##### For a small number of categories → shows all categories.
# ##### For many categories → may simplify the legend.
# ##### **legend='brief'**
# ##### Shows a summarized legend.
# ##### Mainly useful when the hue variable is numeric and contains many unique values.
# ##### **legend='full'**
# ##### Displays every unique value in the legend.
# ##### legend=False : Removes the legend completely.
# | Value | Meaning                           | Best For           |
# | ----- | --------------------------------- | ------------------ |
# | auto  | Seaborn decides                   | General use        |
# | brief | Shows fewer representative values | Large numeric data |
# | full  | Shows all values                  | Detailed analysis  |
# | False | No legend                         | Clean plots        |

# %%
sns.lineplot(data=df,x='Degree Yop',y='Degree Percentage',hue='Courses Taken',marker='D',dashes=False,legend='full')
plt.title('Scatter Plot (Degree YOP VS PERCENTAGE',fontsize=15,color='red',fontstyle='italic',fontfamily='Times New Roman')
plt.xlabel('Degree YOP',color='purple',fontsize=12)
plt.ylabel('Degree Percentage',color='purple',fontsize=12)
plt.xticks(color='blue',rotation=90)
plt.yticks(color='blue',rotation=0)
plt.grid(True)
plt.legend(loc='best',bbox_to_anchor=(1.05,1),)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### **Sizes :**
# ##### Controls minimum and maximum marker size.
# ##### **Syntax :** sizes=(min,max)
# ##### **Example :** sns.scatterplot(
#     data=df,
#     x='Age',
#     y='Salary',
#     size='Experience',
#     sizes=(100,500)
# )

# %%
sns.lineplot(data=df,x='Degree Yop',y='Degree Percentage',hue='Courses Taken',marker='D',size='Admission Type',sizes=(1,5))
plt.title('Scatter Plot (Degree YOP VS PERCENTAGE',fontsize=15,color='red',fontstyle='italic',fontfamily='Times New Roman')
plt.xlabel('Degree YOP',color='purple',fontsize=12)
plt.ylabel('Degree Percentage',color='purple',fontsize=12)
plt.xticks(color='blue',rotation=90)
plt.yticks(color='blue',rotation=0)
plt.grid(True)
plt.legend(loc='best',bbox_to_anchor=(1.05,1),)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### **alpha :**
# ##### Transparency.
# ##### **Syntax :** alpha=0.7

# %%
sns.lineplot(data=df,x='Degree Yop',y='Degree Percentage',hue='Courses Taken',marker='D',size='Admission Type',sizes=(1,5),alpha=0.5)
plt.title('Scatter Plot (Degree YOP VS PERCENTAGE',fontsize=15,color='red',fontstyle='italic',fontfamily='Times New Roman')
plt.xlabel('Degree YOP',color='purple',fontsize=12)
plt.ylabel('Degree Percentage',color='purple',fontsize=12)
plt.xticks(color='blue',rotation=90)
plt.yticks(color='blue',rotation=0)
plt.grid(True)
plt.legend(loc='best',bbox_to_anchor=(1.05,1),)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### **linewidth :**
# ##### Line thickness.

# %%
sns.lineplot(data=df,x='Degree Yop',y='Degree Percentage',hue='Courses Taken',marker='D',size='Admission Type',alpha=0.5,linewidth=10)
plt.title('Scatter Plot (Degree YOP VS PERCENTAGE',fontsize=15,color='red',fontstyle='italic',fontfamily='Times New Roman')
plt.xlabel('Degree YOP',color='purple',fontsize=12)
plt.ylabel('Degree Percentage',color='purple',fontsize=12)
plt.xticks(color='blue',rotation=90)
plt.yticks(color='blue',rotation=0)
plt.grid(True)
plt.legend(loc='best',bbox_to_anchor=(1.05,1),)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### **estimator :**
# ##### Aggregation function.When multiple observations exist for the same X-value.
# ##### Values : mean, median, sum, min & max

# %%
import numpy as np
sns.lineplot(data=df,x='Degree Yop',y='Degree Percentage',hue='Courses Taken',marker='D',size='Admission Type',estimator=np.max)
plt.title('Scatter Plot (Degree YOP VS PERCENTAGE',fontsize=15,color='red',fontstyle='italic',fontfamily='Times New Roman')
plt.xlabel('Degree YOP',color='purple',fontsize=12)
plt.ylabel('Degree Percentage',color='purple',fontsize=12)
plt.xticks(color='blue',rotation=90)
plt.yticks(color='blue',rotation=0)
plt.grid(True)
plt.legend(loc='best',bbox_to_anchor=(1.05,1),)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### **errorbar :**
# ##### Displays uncertainty around estimates.
# ##### Values : errorbar=None, errorbar='sd', errorbar=('ci',95), errorbar=('ci',99)
# ##### **Example :** errorbar=('ci',95) -> Shows 95% Confidence Interval.

# %%
import numpy as np
sns.lineplot(data=df,x='Degree Yop',y='Degree Percentage',hue='Courses Taken',marker='D',size='Admission Type',estimator=np.max,errorbar=('ci',95))
plt.title('Scatter Plot (Degree YOP VS PERCENTAGE',fontsize=15,color='red',fontstyle='italic',fontfamily='Times New Roman')
plt.xlabel('Degree YOP',color='purple',fontsize=12)
plt.ylabel('Degree Percentage',color='purple',fontsize=12)
plt.xticks(color='blue',rotation=90)
plt.yticks(color='blue',rotation=0)
plt.grid(True)
plt.legend(loc='best',bbox_to_anchor=(1.05,1),)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### **Example :**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df=pd.DataFrame({
    'Month':['Jan','Feb','Mar','Apr','May'],
    'Sales':[100,120,150,180,200],
    'Year':['2025','2025','2025','2025','2025'],
    'Profit':[10,15,20,25,30]
})

plt.figure(figsize=(10,6))

sns.lineplot(
    data=df,
    x='Month',
    y='Sales',
    hue='Year',
    marker='D',
    markers=True,
    linewidth=3,
    palette='Set2',
    alpha=0.8,
    legend='full'
)

plt.title('Monthly Sales Trend')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.grid(True)

plt.show()
